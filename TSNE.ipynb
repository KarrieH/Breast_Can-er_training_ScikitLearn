# %%
from sklearn.datasets import load_breast_cancer
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
cancer = load_breast_cancer()

# %%
X, y = cancer.data, cancer.target

# %%
X.shape
# Out:
# (569, 30)

# %%
y.shape
# Out:
# (569,)

# %%
tsne = TSNE(random_state = 0)

# %%
X_embedded = tsne.fit_transform(X)

# %%
X_embedded.shape
# Out:
# (569, 2)

# %%
X_embedded
# Out:
# array([[ -9.784096 , -33.277435 ],
#        [-10.135075 , -30.423965 ],
#        [ -5.3082476, -29.263031 ],
#        ...,
#        [ 10.919813 , -19.07272  ],
#        [ -7.8811097, -30.065409 ],
#        [-35.00592  ,  -1.5404571]], dtype=float32)

# %%
target_ids = range(len(cancer.target_names))

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'b'
for i, c, label in zip(target_ids, colors, cancer.target_names):
    plt.scatter(X_embedded[y == i, 0], X_embedded[y == i, 1], c=c, label=label, alpha=0.3)
plt.legend()
plt.xlabel("t-SNE признак 0")
plt.ylabel("t-SNE признак 1")
plt.show()

# %%
# по графику видно, что некоторые синие метки почти полностью перекрывают красные. 
# Произвести классификацию с точным разделением на два класса не получится. 
# В любом случае будем получать небольшую погрешность в правильности, не достигнув 100%.
